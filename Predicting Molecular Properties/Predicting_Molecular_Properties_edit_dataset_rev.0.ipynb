# %% [markdown]
# #Marge datasets and make big training dataset

# %%
import numpy as np # linear algebra
import math
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.framework import ops
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pandas.plotting import scatter_matrix

# %%
#Load data
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

#Load sub data
sub = pd.read_csv("sample_submission.csv")
structures = pd.read_csv("structures.csv")
scalar_coupling_contributions = pd.read_csv("scalar_coupling_contributions.csv")
magnetic_shielding_tesors = pd.read_csv("magnetic_shielding_tensors.csv")
dipole_moments = pd.read_csv("dipole_moments.csv")
potential_energy = pd.read_csv("potential_energy.csv")
mulliken_charges = pd.read_csv("mulliken_charges.csv")

# %%
print(train.shape)
print(test.shape)
print(sub.shape)
print(structures.shape)
print(scalar_coupling_contributions.shape)
print(magnetic_shielding_tesors.shape)
print(dipole_moments.shape)
print(potential_energy.shape)
print(mulliken_charges.shape)

#check number of unique data 
print(train["molecule_name"].nunique())
print(test["molecule_name"].nunique())
print(structures["atom"].nunique())
print(train["type"].nunique())
# Out:
# (4658147, 6)
# (2505542, 5)
# (2505542, 2)
# (2358657, 6)
# (4658147, 8)
# (1533537, 11)
# (85003, 4)
# (85003, 2)
# (1533537, 3)
# 85003
# 45772
# 5
# 8

# %% [markdown]
# I want to marge dataset and add new features.

# %%
def map_atom_info(df, atom_idx):
    df = pd.merge(df, structures, how = 'left',
                  left_on  = ['molecule_name', f'atom_index_{atom_idx}'],
                  right_on = ['molecule_name',  'atom_index'])
    
    df = df.drop('atom_index', axis=1)
    df = df.rename(columns={'atom': f'atom_{atom_idx}',
                            'x': f'x_{atom_idx}',
                            'y': f'y_{atom_idx}',
                            'z': f'z_{atom_idx}'})
    return df

# %% [markdown]
# Now, marge 2 datasets!

# %%
train_structure = map_atom_info(train, 0)
train_structure = map_atom_info(train_structure, 1)

# %%
train_structure.head(20)
# Out:
#     id     molecule_name  atom_index_0  atom_index_1  type  \
# 0    0  dsgdb9nsd_000001             1             0  1JHC
# 1    1  dsgdb9nsd_000001             1             2  2JHH
# 2    2  dsgdb9nsd_000001             1             3  2JHH
# 3    3  dsgdb9nsd_000001             1             4  2JHH
# 4    4  dsgdb9nsd_000001             2             0  1JHC
# 5    5  dsgdb9nsd_000001             2             3  2JHH
# 6    6  dsgdb9nsd_000001             2             4  2JHH
# 7    7  dsgdb9nsd_000001             3             0  1JHC
# 8    8  dsgdb9nsd_000001             3             4  2JHH
# 9    9  dsgdb9nsd_000001             4             0  1JHC
# 10  10  dsgdb9nsd_000002             1             0  1JHN
# 11  11  dsgdb9nsd_000002             1             2  2JHH
# 12  12  dsgdb9nsd_000002             1             3  2JHH
# 13  13  dsgdb9nsd_000002             2             0  1JHN
# 14  14  dsgdb9nsd_000002             2             3  2JHH
# 15  15  dsgdb9nsd_000002             3             0  1JHN
# 16  16  dsgdb9nsd_000003             1             2  2JHH
# 17  17  dsgdb9nsd_000005             2             0  1JHC
# 18  18  dsgdb9nsd_000005             2             1  2JHN
# 19  19  dsgdb9nsd_000007             2             0  1JHC
#
#     scalar_coupling_constant atom_0       x_0       y_0       z_0 atom_1  \
# 0                   84.80760      H  0.002150 -0.006031  0.001976      C
# 1                  -11.25700      H  0.002150 -0.006031  0.001976      H
# 2                  -11.25480      H  0.002150 -0.006031  0.001976      H
# 3                  -11.25430      H  0.002150 -0.006031  0.001976      H
# 4                   84.80740      H  1.011731  1.463751  0.000277      C
# 5                  -11.25410      H  1.011731  1.463751  0.000277      H
# 6                  -11.25480      H  1.011731  1.463751  0.000277      H
# 7                   84.80930      H -0.540815  1.447527 -0.876644      C
# 8                  -11.25430      H -0.540815  1.447527 -0.876644      H
# 9                   84.80950      H -0.523814  1.437933  0.906397      C
# 10                  32.68890      H  0.017257  0.012545 -0.027377      N
# 11                 -11.18660      H  0.017257  0.012545 -0.027377      H
# 12                 -11.17570      H  0.017257  0.012545 -0.027377      H
# 13                  32.68910      H  0.915789  1.358745 -0.028758      N
# 14                 -11.17580      H  0.915789  1.358745 -0.028758      H
# 15                  32.69050      H -0.520278  1.343532 -0.775543      N
# 16                  -9.94641      H  0.064766  0.020572  0.001535      H
# 17                 171.22000      H -0.027803  2.198949  0.014154      C
# 18                   5.18246      H -0.027803  2.198949  0.014154      N
# 19                  83.54290      H  0.994873  1.939743  0.002941      C
#
#          x_1       y_1       z_1
# 0  -0.012698  1.085804  0.008001
# 1   1.011731  1.463751  0.000277
# 2  -0.540815  1.447527 -0.876644
# 3  -0.523814  1.437933  0.906397
# 4  -0.012698  1.085804  0.008001
# 5  -0.540815  1.447527 -0.876644
# 6  -0.523814  1.437933  0.906397
# 7  -0.012698  1.085804  0.008001
# 8  -0.523814  1.437933  0.906397
# 9  -0.012698  1.085804  0.008001
# 10 -0.040426  1.024108  0.062564
# 11  0.915789  1.358745 -0.028758
# 12 -0.520278  1.343532 -0.775543
# 13 -0.040426  1.024108  0.062564
# 14 -0.520278  1.343532 -0.775543
# 15 -0.040426  1.024108  0.062564
# 16  0.871790  1.300792  0.000693
# 17 -0.013324  1.132466  0.008276
# 18  0.002311 -0.019159  0.001929
# 19 -0.018704  1.525582  0.010433

# %%
test_structure = map_atom_info(test, 0)
test_structure = map_atom_info(test_structure, 1)

# %%
test_structure.head(20)
# Out:
#          id     molecule_name  atom_index_0  atom_index_1  type atom_0  \
# 0   4658147  dsgdb9nsd_000004             2             0  2JHC      H
# 1   4658148  dsgdb9nsd_000004             2             1  1JHC      H
# 2   4658149  dsgdb9nsd_000004             2             3  3JHH      H
# 3   4658150  dsgdb9nsd_000004             3             0  1JHC      H
# 4   4658151  dsgdb9nsd_000004             3             1  2JHC      H
# 5   4658152  dsgdb9nsd_000015             3             0  1JHC      H
# 6   4658153  dsgdb9nsd_000015             3             2  3JHC      H
# 7   4658154  dsgdb9nsd_000015             3             4  2JHH      H
# 8   4658155  dsgdb9nsd_000015             3             5  2JHH      H
# 9   4658156  dsgdb9nsd_000015             4             0  1JHC      H
# 10  4658157  dsgdb9nsd_000015             4             2  3JHC      H
# 11  4658158  dsgdb9nsd_000015             4             5  2JHH      H
# 12  4658159  dsgdb9nsd_000015             5             0  1JHC      H
# 13  4658160  dsgdb9nsd_000015             5             2  3JHC      H
# 14  4658161  dsgdb9nsd_000015             6             0  3JHC      H
# 15  4658162  dsgdb9nsd_000015             6             2  1JHC      H
# 16  4658163  dsgdb9nsd_000015             6             7  2JHH      H
# 17  4658164  dsgdb9nsd_000015             6             8  2JHH      H
# 18  4658165  dsgdb9nsd_000015             7             0  3JHC      H
# 19  4658166  dsgdb9nsd_000015             7             2  1JHC      H
#
#          x_0       y_0       z_0 atom_1       x_1       y_1       z_1
# 0  -1.661639  0.000000  1.000000      C  0.599539  0.000000  1.000000
# 1  -1.661639  0.000000  1.000000      C -0.599539  0.000000  1.000000
# 2  -1.661639  0.000000  1.000000      H  1.661639  0.000000  1.000000
# 3   1.661639  0.000000  1.000000      C  0.599539  0.000000  1.000000
# 4   1.661639  0.000000  1.000000      C -0.599539  0.000000  1.000000
# 5   1.005284  1.810158  0.004656      C -0.014821  1.392412  0.005671
# 6   1.005284  1.810158  0.004656      C  0.637949 -0.553297 -1.113582
# 7   1.005284  1.810158  0.004656      H -0.546896  1.793435 -0.872511
# 8   1.005284  1.810158  0.004656      H -0.530029  1.722920  0.911017
# 9  -0.546896  1.793435 -0.872511      C -0.014821  1.392412  0.005671
# 10 -0.546896  1.793435 -0.872511      C  0.637949 -0.553297 -1.113582
# 11 -0.546896  1.793435 -0.872511      H -0.530029  1.722920  0.911017
# 12 -0.530029  1.722920  0.911017      C -0.014821  1.392412  0.005671
# 13 -0.530029  1.722920  0.911017      C  0.637949 -0.553297 -1.113582
# 14  0.139938 -0.255993 -2.050984      C -0.014821  1.392412  0.005671
# 15  0.139938 -0.255993 -2.050984      C  0.637949 -0.553297 -1.113582
# 16  0.139938 -0.255993 -2.050984      H  1.692653 -0.238684 -1.174777
# 17  0.139938 -0.255993 -2.050984      H  0.599594 -1.641802 -1.024076
# 18  1.692653 -0.238684 -1.174777      C -0.014821  1.392412  0.005671
# 19  1.692653 -0.238684 -1.174777      C  0.637949 -0.553297 -1.113582

# %% [markdown]
# OK, next let's calculate distunce of atoms.
# The distunce of atoms is sqrt((x_0 - x_1)^2 + (y_0 - y_1)^2 + (z_0 - z_1)^2), so I use numpy.linalg.norm.

# %%
train_p_0 = train_structure[['x_0', 'y_0', 'z_0']].values
train_p_1 = train_structure[['x_1', 'y_1', 'z_1']].values
train_structure['dist'] = np.linalg.norm(train_p_0 - train_p_1, axis=1)
train_structure.head(10)
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
# 5   5  dsgdb9nsd_000001             2             3  2JHH
# 6   6  dsgdb9nsd_000001             2             4  2JHH
# 7   7  dsgdb9nsd_000001             3             0  1JHC
# 8   8  dsgdb9nsd_000001             3             4  2JHH
# 9   9  dsgdb9nsd_000001             4             0  1JHC
#
#    scalar_coupling_constant atom_0       x_0       y_0       z_0 atom_1  \
# 0                   84.8076      H  0.002150 -0.006031  0.001976      C
# 1                  -11.2570      H  0.002150 -0.006031  0.001976      H
# 2                  -11.2548      H  0.002150 -0.006031  0.001976      H
# 3                  -11.2543      H  0.002150 -0.006031  0.001976      H
# 4                   84.8074      H  1.011731  1.463751  0.000277      C
# 5                  -11.2541      H  1.011731  1.463751  0.000277      H
# 6                  -11.2548      H  1.011731  1.463751  0.000277      H
# 7                   84.8093      H -0.540815  1.447527 -0.876644      C
# 8                  -11.2543      H -0.540815  1.447527 -0.876644      H
# 9                   84.8095      H -0.523814  1.437933  0.906397      C
#
#         x_1       y_1       z_1      dist
# 0 -0.012698  1.085804  0.008001  1.091953
# 1  1.011731  1.463751  0.000277  1.783120
# 2 -0.540815  1.447527 -0.876644  1.783147
# 3 -0.523814  1.437933  0.906397  1.783157
# 4 -0.012698  1.085804  0.008001  1.091952
# 5 -0.540815  1.447527 -0.876644  1.783158
# 6 -0.523814  1.437933  0.906397  1.783148
# 7 -0.012698  1.085804  0.008001  1.091946
# 8 -0.523814  1.437933  0.906397  1.783148
# 9 -0.012698  1.085804  0.008001  1.091948

# %%
test_p_0 = test_structure[['x_0', 'y_0', 'z_0']].values
test_p_1 = test_structure[['x_1', 'y_1', 'z_1']].values
test_structure['dist'] = np.linalg.norm(test_p_0 - test_p_1, axis=1)
test_structure.head(10)
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type atom_0  \
# 0  4658147  dsgdb9nsd_000004             2             0  2JHC      H
# 1  4658148  dsgdb9nsd_000004             2             1  1JHC      H
# 2  4658149  dsgdb9nsd_000004             2             3  3JHH      H
# 3  4658150  dsgdb9nsd_000004             3             0  1JHC      H
# 4  4658151  dsgdb9nsd_000004             3             1  2JHC      H
# 5  4658152  dsgdb9nsd_000015             3             0  1JHC      H
# 6  4658153  dsgdb9nsd_000015             3             2  3JHC      H
# 7  4658154  dsgdb9nsd_000015             3             4  2JHH      H
# 8  4658155  dsgdb9nsd_000015             3             5  2JHH      H
# 9  4658156  dsgdb9nsd_000015             4             0  1JHC      H
#
#         x_0       y_0       z_0 atom_1       x_1       y_1       z_1      dist
# 0 -1.661639  0.000000  1.000000      C  0.599539  0.000000  1.000000  2.261178
# 1 -1.661639  0.000000  1.000000      C -0.599539  0.000000  1.000000  1.062099
# 2 -1.661639  0.000000  1.000000      H  1.661639  0.000000  1.000000  3.323277
# 3  1.661639  0.000000  1.000000      C  0.599539  0.000000  1.000000  1.062099
# 4  1.661639  0.000000  1.000000      C -0.599539  0.000000  1.000000  2.261178
# 5  1.005284  1.810158  0.004656      C -0.014821  1.392412  0.005671  1.102328
# 6  1.005284  1.810158  0.004656      C  0.637949 -0.553297 -1.113582  2.640324
# 7  1.005284  1.810158  0.004656      H -0.546896  1.793435 -0.872511  1.782964
# 8  1.005284  1.810158  0.004656      H -0.530029  1.722920  0.911017  1.785017
# 9 -0.546896  1.793435 -0.872511      C -0.014821  1.392412  0.005671  1.102327

# %% [markdown]
# Academically, atomic number become large, scalar coupling constant also become large.
# So, I want to add atomic number information in dataset.

# %%
train_structure["atomic_number_0"]=train_structure["atom_0"].replace("H", 1).replace("C", 6).replace("N", 7).replace("O", 8).replace("F", 9)
train_structure["atomic_number_1"]=train_structure["atom_1"].replace("H", 1).replace("C", 6).replace("N", 7).replace("O", 8).replace("F", 9)

# %%
train_structure.head(10)
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
# 5   5  dsgdb9nsd_000001             2             3  2JHH
# 6   6  dsgdb9nsd_000001             2             4  2JHH
# 7   7  dsgdb9nsd_000001             3             0  1JHC
# 8   8  dsgdb9nsd_000001             3             4  2JHH
# 9   9  dsgdb9nsd_000001             4             0  1JHC
#
#    scalar_coupling_constant atom_0       x_0       y_0       z_0 atom_1  \
# 0                   84.8076      H  0.002150 -0.006031  0.001976      C
# 1                  -11.2570      H  0.002150 -0.006031  0.001976      H
# 2                  -11.2548      H  0.002150 -0.006031  0.001976      H
# 3                  -11.2543      H  0.002150 -0.006031  0.001976      H
# 4                   84.8074      H  1.011731  1.463751  0.000277      C
# 5                  -11.2541      H  1.011731  1.463751  0.000277      H
# 6                  -11.2548      H  1.011731  1.463751  0.000277      H
# 7                   84.8093      H -0.540815  1.447527 -0.876644      C
# 8                  -11.2543      H -0.540815  1.447527 -0.876644      H
# 9                   84.8095      H -0.523814  1.437933  0.906397      C
#
#         x_1       y_1       z_1      dist  atomic_number_0  atomic_number_1
# 0 -0.012698  1.085804  0.008001  1.091953                1                6
# 1  1.011731  1.463751  0.000277  1.783120                1                1
# 2 -0.540815  1.447527 -0.876644  1.783147                1                1
# 3 -0.523814  1.437933  0.906397  1.783157                1                1
# 4 -0.012698  1.085804  0.008001  1.091952                1                6
# 5 -0.540815  1.447527 -0.876644  1.783158                1                1
# 6 -0.523814  1.437933  0.906397  1.783148                1                1
# 7 -0.012698  1.085804  0.008001  1.091946                1                6
# 8 -0.523814  1.437933  0.906397  1.783148                1                1
# 9 -0.012698  1.085804  0.008001  1.091948                1                6

# %%
test_structure["atomic_number_0"]=test_structure["atom_0"].replace("H", 1).replace("C", 6).replace("N", 7).replace("O", 8).replace("F", 9)
test_structure["atomic_number_1"]=test_structure["atom_1"].replace("H", 1).replace("C", 6).replace("N", 7).replace("O", 8).replace("F", 9)

# %%
test_structure.head(10)
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type atom_0  \
# 0  4658147  dsgdb9nsd_000004             2             0  2JHC      H
# 1  4658148  dsgdb9nsd_000004             2             1  1JHC      H
# 2  4658149  dsgdb9nsd_000004             2             3  3JHH      H
# 3  4658150  dsgdb9nsd_000004             3             0  1JHC      H
# 4  4658151  dsgdb9nsd_000004             3             1  2JHC      H
# 5  4658152  dsgdb9nsd_000015             3             0  1JHC      H
# 6  4658153  dsgdb9nsd_000015             3             2  3JHC      H
# 7  4658154  dsgdb9nsd_000015             3             4  2JHH      H
# 8  4658155  dsgdb9nsd_000015             3             5  2JHH      H
# 9  4658156  dsgdb9nsd_000015             4             0  1JHC      H
#
#         x_0       y_0       z_0 atom_1       x_1       y_1       z_1  \
# 0 -1.661639  0.000000  1.000000      C  0.599539  0.000000  1.000000
# 1 -1.661639  0.000000  1.000000      C -0.599539  0.000000  1.000000
# 2 -1.661639  0.000000  1.000000      H  1.661639  0.000000  1.000000
# 3  1.661639  0.000000  1.000000      C  0.599539  0.000000  1.000000
# 4  1.661639  0.000000  1.000000      C -0.599539  0.000000  1.000000
# 5  1.005284  1.810158  0.004656      C -0.014821  1.392412  0.005671
# 6  1.005284  1.810158  0.004656      C  0.637949 -0.553297 -1.113582
# 7  1.005284  1.810158  0.004656      H -0.546896  1.793435 -0.872511
# 8  1.005284  1.810158  0.004656      H -0.530029  1.722920  0.911017
# 9 -0.546896  1.793435 -0.872511      C -0.014821  1.392412  0.005671
#
#        dist  atomic_number_0  atomic_number_1
# 0  2.261178                1                6
# 1  1.062099                1                6
# 2  3.323277                1                1
# 3  1.062099                1                6
# 4  2.261178                1                6
# 5  1.102328                1                6
# 6  2.640324                1                6
# 7  1.782964                1                1
# 8  1.785017                1                1
# 9  1.102327                1                6

# %% [markdown]
# In addition, maybe coupling number have effect for scalar coupling constant, let's add that.

# %%
train_structure["coupling_number_0"]=train_structure["atom_0"].replace("H", 1).replace("C", 4).replace("N", 3).replace("O", 2).replace("F", 1)
train_structure["coupling_number_1"]=train_structure["atom_1"].replace("H", 1).replace("C", 4).replace("N", 3).replace("O", 2).replace("F", 1)

# %%
test_structure["coupling_number_0"]=test_structure["atom_0"].replace("H", 1).replace("C", 4).replace("N", 3).replace("O", 2).replace("F", 1)
test_structure["coupling_number_1"]=test_structure["atom_1"].replace("H", 1).replace("C", 4).replace("N", 3).replace("O", 2).replace("F", 1)

# %%
test_structure.head(10)
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type atom_0  \
# 0  4658147  dsgdb9nsd_000004             2             0  2JHC      H
# 1  4658148  dsgdb9nsd_000004             2             1  1JHC      H
# 2  4658149  dsgdb9nsd_000004             2             3  3JHH      H
# 3  4658150  dsgdb9nsd_000004             3             0  1JHC      H
# 4  4658151  dsgdb9nsd_000004             3             1  2JHC      H
# 5  4658152  dsgdb9nsd_000015             3             0  1JHC      H
# 6  4658153  dsgdb9nsd_000015             3             2  3JHC      H
# 7  4658154  dsgdb9nsd_000015             3             4  2JHH      H
# 8  4658155  dsgdb9nsd_000015             3             5  2JHH      H
# 9  4658156  dsgdb9nsd_000015             4             0  1JHC      H
#
#         x_0       y_0       z_0 atom_1       x_1       y_1       z_1  \
# 0 -1.661639  0.000000  1.000000      C  0.599539  0.000000  1.000000
# 1 -1.661639  0.000000  1.000000      C -0.599539  0.000000  1.000000
# 2 -1.661639  0.000000  1.000000      H  1.661639  0.000000  1.000000
# 3  1.661639  0.000000  1.000000      C  0.599539  0.000000  1.000000
# 4  1.661639  0.000000  1.000000      C -0.599539  0.000000  1.000000
# 5  1.005284  1.810158  0.004656      C -0.014821  1.392412  0.005671
# 6  1.005284  1.810158  0.004656      C  0.637949 -0.553297 -1.113582
# 7  1.005284  1.810158  0.004656      H -0.546896  1.793435 -0.872511
# 8  1.005284  1.810158  0.004656      H -0.530029  1.722920  0.911017
# 9 -0.546896  1.793435 -0.872511      C -0.014821  1.392412  0.005671
#
#        dist  atomic_number_0  atomic_number_1  coupling_number_0  \
# 0  2.261178                1                6                  1
# 1  1.062099                1                6                  1
# 2  3.323277                1                1                  1
# 3  1.062099                1                6                  1
# 4  2.261178                1                6                  1
# 5  1.102328                1                6                  1
# 6  2.640324                1                6                  1
# 7  1.782964                1                1                  1
# 8  1.785017                1                1                  1
# 9  1.102327                1                6                  1
#
#    coupling_number_1
# 0                  4
# 1                  4
# 2                  1
# 3                  4
# 4                  4
# 5                  4
# 6                  4
# 7                  1
# 8                  1
# 9                  4

# %% [markdown]
# Next, I want to add number of atoms in molecule....., but my code didn't work well no matter how many challanges I tried.
# Please give me a good idea!

# %%
#train_structure.groupby("molecule_name")
